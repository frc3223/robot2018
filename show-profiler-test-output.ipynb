# %%
from frc3223_azurite.data import read_csv
from matplotlib import pyplot as plt

# %%
data = read_csv("./logs/test_profiler4.csv")
ts = data['t']
vs = data['v']
xs = data['pos']
accels = data['a']

# %%
s = 0
e = len(ts)
plt.plot(ts[s:e], vs[s:e])
plt.show()
plt.plot(ts[s:e], accels[s:e])
plt.show()
plt.plot(ts[s:e], xs[s:e])
plt.show()

# %%
ts
# Out:
# array([0.  , 0.02, 0.04, 0.06, 0.08, 0.1 , 0.12, 0.14, 0.16, 0.18, 0.2 ,
#        0.22, 0.24, 0.26, 0.28, 0.3 , 0.32, 0.34, 0.36, 0.38, 0.4 , 0.42,
#        0.44, 0.46, 0.48, 0.5 , 0.52, 0.54, 0.56, 0.58, 0.6 , 0.62, 0.64,
#        0.66, 0.68, 0.7 , 0.72, 0.74, 0.76, 0.78, 0.8 , 0.82, 0.84, 0.86,
#        0.88, 0.9 , 0.92, 0.94])

# %%
vs
# Out:
# array([ 0.00000000e+00, -4.00000000e-01, -8.00000000e-01, -1.20000000e+00,
#        -1.60000000e+00, -2.00000000e+00, -2.40000000e+00, -2.80000000e+00,
#        -3.20000000e+00, -3.60000000e+00, -4.00000000e+00, -4.40000000e+00,
#        -4.80000000e+00, -5.20000000e+00, -5.60000000e+00, -6.00000000e+00,
#        -6.40000000e+00, -6.80000000e+00, -7.20000000e+00, -7.60000000e+00,
#        -8.00000000e+00, -8.40000000e+00, -8.80000000e+00, -9.20000000e+00,
#        -8.80000000e+00, -8.40000000e+00, -8.00000000e+00, -7.60000000e+00,
#        -7.20000000e+00, -6.80000000e+00, -6.40000000e+00, -6.00000000e+00,
#        -5.60000000e+00, -5.20000000e+00, -4.80000000e+00, -4.40000000e+00,
#        -4.00000000e+00, -3.60000000e+00, -3.20000000e+00, -2.80000000e+00,
#        -2.40000000e+00, -2.00000000e+00, -1.60000000e+00, -1.20000000e+00,
#        -8.00000000e-01, -4.00000000e-01,  7.77156117e-16,  0.00000000e+00])
