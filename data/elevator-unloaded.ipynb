# %%
from frc3223_azurite.data import show_data
from matplotlib import pyplot as plt
from scipy import stats

# %%
show_data("elevator3-majig.csv", time_key='time')
# Out:
# s=0
# e=138

# %%
voltage = [3.13,6.02,8.66,11]
velocity = [ .3,.66,1,1.3]
plt.plot(velocity, voltage)
plt.show()
stats.linregress(velocity, voltage)
# Out:
# LinregressResult(slope=7.861195632718812, intercept=0.7956255593341686, rvalue=0.9999694349500964, pvalue=3.0565049903619204e-05, stderr=0.04346214082516721)
